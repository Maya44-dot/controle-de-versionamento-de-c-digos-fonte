# %% [markdown]
# <a href="https://colab.research.google.com/github/Maya44-dot/controle-de-versionamento-de-c-digos-fonte/blob/main/aula_1_21-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = " João Silva "
idade = 25
Profissao = "Desenvolvedor"
print(f"seu nome é {nome} sua idade é {idade} sua profissão {Profissao}")
# Out:
# seu nome é  João Silva  sua idade é 25 sua profissão Desenvolvedor

# %%
Produto = "Notebook"
Marca = "Dell"
Preço = "4.500,00"
print(f" seu produto é {Produto} sua marca é {Marca} o Preço é {Preço}")
# Out:
#  seu produto é Notebook sua marca é Dell o Preço é 4.500,00

# %%
Num1 = float(input("Digite seu numero"))
Num2 = float(input("Digite seu numero"))
Soma = Num1 + Num2
Subtracao = Num1 - Num2
mult = Num1 * Num2
div = Num1 / Num2
potenciacao = Num1 ** Num2
print(f" o resultado da some é {Soma}" )
print(f" o resultado da some é {Subtracao}" )
print(f" o resultado da some é {mult}" )
print(f" o resultado da some é {div}" )
print(f" o resultado da some é {potenciacao}" )
# Out:
# Digite seu numero12
# Digite seu numero6
#  o resultado da some é 18.0
#  o resultado da some é 6.0
#  o resultado da some é 72.0
#  o resultado da some é 2.0
#  o resultado da some é 2985984.0

# %%
Num1 = float(input("Digite seu numero"))
Num2 = float(input("Digite seu numero"))
Soma = Num1 + Num2
Subtracao = Num1 - Num2
mult = Num1 * Num2
div = Num1 / Num2
potenciacao = Num1 ** Num2
print(f" o resultado da some é {Soma}" )
print(f" o resultado da some é {Subtracao}" )
print(f" o resultado da some é {mult}" )
print(f" o resultado da some é {div}" )
print(f" o resultado da some é {potenciacao}" )
# Out:
# Digite seu numero7
# Digite seu numero2
#  o resultado da some é 9.0
#  o resultado da some é 5.0
#  o resultado da some é 14.0
#  o resultado da some é 3.5
#  o resultado da some é 49.0

# %%
Num1 = float(input("Digite seu numero"))
Num2 = float(input("Digite seu numero"))
Soma = Num1 + Num2
Subtracao = Num1 - Num2
mult = Num1 * Num2
div = Num1 / Num2
potenciacao = Num1 ** Num2
print(f" o resultado da some é {Soma}" )
print(f" o resultado da some é {Subtracao}" )
print(f" o resultado da some é {mult}" )
print(f" o resultado da some é {div}" )
print(f" o resultado da some é {potenciacao}" )
# Out:
# Digite seu numero15
# Digite seu numero5
#  o resultado da some é 20.0
#  o resultado da some é 10.0
#  o resultado da some é 75.0
#  o resultado da some é 3.0
#  o resultado da some é 759375.0

# %%
#lista
materiais = ("Matematica, ciencias e portugues")
print(f"materiais: {materiais}")
#dicionario
Aluno = {
"Nome do aluno": "Carlos",
"Idade": 18,
"Curso": "ADS"
}
print(f"informações do aluno: {Aluno}")
# Out:
# materiais: Matematica, ciencias e portugues
# informações do aluno: {'Nome do aluno': 'Carlos', 'Idade': 18, 'Curso': 'ADS'}

# %%
#lista
acessorios = ("Carregador por Indução, Compressor de Ar Portátil, Câmera de Ré")
print(f"materiais: {acessorios}")
#dicionario
Aluno = {
"Marca": "Toyota",
"Modelo": "Corolla XEi",
"Ano": 2014
}
print(f"informações do aluno: {Aluno}")
# Out:
# materiais: Carregador por Indução, Compressor de Ar Portátil, Câmera de Ré
# informações do aluno: {'Marca': 'Toyota', 'Modelo': 'Corolla XEi', 'Ano': 2014}
